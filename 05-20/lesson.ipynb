# %%
#學生總分為300分      
#有些學生可以加分5%     

scores =  int(input("請輸入學生分數(最高300分):"))
is_add = input("學生是否符合加分條件?(y,n)")

if is_add == "y":
    scores = scores * 1.05

scores = int(scores + 0.5)

if scores >300:
    scores = 300
    
print("學生分數:",scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 #學生總分為300分
#       2 #有些學生可以加分5%
#       3
# ----> 4 scores =  int(input("請輸入學生分數(最高300分):"))
#       5 is_add = input("學生是否符合加分條件?(y,n)")
#       6
#       7 if is_add == "y":
#
# ValueError: invalid literal for int() with base 10: '250a'
